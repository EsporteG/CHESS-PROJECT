# %%
import pandas as pd

# %%
df = pd.read_excel('raw_chess_players_data\lpsupi_archive.xlsx')
df = df.dropna(subset=['url'])
df = list(df['pgn'])
df = list(map(lambda value: value.split('\n\n')[0].split('\n'), df))
df_f = []

for png in df:
    df = list(map(lambda value: value.strip("[").strip("]").strip('\s').rstrip('"').replace(" ","").split('"'), png))
    df_f.append(df)
    i = 1
df_final = pd.DataFrame()

for pgn_pro in df_f:
    df = pd.DataFrame(pgn_pro)
    df = df.transpose()
    df = df.rename(columns=df.iloc[0]).drop(df.index[0])
    df['match id'] = i
    i=i+1
    df_final = pd.concat([df_final,df])
df_final.head()
# Out:
#        Event       Site        Date Round        White         Black Result  \
# 1  LiveChess  Chess.com  2013.04.25     -       LPSupi  FaustusLevis    1-0
# 1  LiveChess  Chess.com  2013.04.25     -     Ganaazam        LPSupi    0-1
# 1  LiveChess  Chess.com  2013.04.25     -  gianuccio55        LPSupi    1-0
# 1  LiveChess  Chess.com  2016.07.31     -       LPSupi     KristianT    1-0
# 1  LiveChess  Chess.com  2016.07.31     -       LPSupi  shahinkoulin    1-0
#
#                                      CurrentPosition Timezone  ECO  ...  \
# 1  1k1r3r/ppp1R1p1/5p2/5Q1p/2P2Bn1/7N/PP3PP1/R4BK...      UTC  C42  ...
# 1              5bk1/3R1p2/4p2p/2p1q3/8/8/5PPP/5K2w--      UTC  B20  ...
# 1  rnbqk1nr/ppppp1bp/6p1/5p2/2P5/2N1PN2/PP1P1PPP/...      UTC  A10  ...
# 1    6k1/1bp2rp1/pqp1pPQp/4P3/2P3P1/1P6/P5BP/3R3Kb--      UTC  E10  ...
# 1    1r3rk1/5pp1/2B2np1/1pB5/p7/2Q3P1/P3RP1P/5RK1b--      UTC  D12  ...
#
#                     Termination StartTime     EndDate   EndTime  \
# 1        LPSupiwonbyresignation  13:04:03  2013.04.25  13:08:30
# 1               LPSupiwonontime  13:08:55  2013.04.25  13:12:47
# 1  gianuccio55won-gameabandoned  13:13:08  2013.04.25  13:14:57
# 1        LPSupiwonbyresignation  00:36:35  2016.07.31  00:41:08
# 1        LPSupiwonbyresignation  03:27:36  2016.07.31  03:31:22
#
#                                          Link match id Tournament SetUp  FEN  \
# 1   https://www.chess.com/game/live/501521359        1        NaN   NaN  NaN
# 1   https://www.chess.com/game/live/501523591        2        NaN   NaN  NaN
# 1   https://www.chess.com/game/live/501525590        3        NaN   NaN  NaN
# 1  https://www.chess.com/game/live/1672982691        4        NaN   NaN  NaN
# 1  https://www.chess.com/game/live/1673096423        5        NaN   NaN  NaN
#
#   Variant
# 1     NaN
# 1     NaN
# 1     NaN
# 1     NaN
# 1     NaN
#
# [5 rows x 26 columns]
